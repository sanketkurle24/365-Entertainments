# %% [markdown]
# <a href="https://colab.research.google.com/github/SanketKurle24/365-Entertainments/blob/main/Suryanamaskar_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir suryanamaskar

# %%
from bing_image_downloader import downloader

downloader.download("Pranamasana",limit=15, output_dir="suryanamaskar")
downloader.download("Hasta Utthanasana",limit=15, output_dir="suryanamaskar")
downloader.download("Padahastasana", limit=15,output_dir="suryanamaskar")
downloader.download("Ashwa Sanchalanasana",limit=15, output_dir="suryanamaskar")
downloader.download("Chaturanga Dandasana",limit=15, output_dir="suryanamaskar")
downloader.download("Ashtanga Namaskar",limit=15, output_dir="suryanamaskar")
downloader.download("Bhujangasana",limit=15, output_dir="suryanamaskar")
downloader.download("Adho Mukha Svanasana",limit=15, output_dir="suryanamaskar")
downloader.download("Ashwa Sanchalanasana",limit=15, output_dir="suryanamaskar")
# Out:
# [%] Downloading Images to /content/suryanamaskar/Pranamasana
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 15 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://1.bp.blogspot.com/-SV4gaNvgFU8/V7aluA5AfbI/AAAAAAAACmQ/IpHGOVbmPQAMZ-o0m8yLRMpGjXRoRIfKACLcB/s1600/Surya%2BNamaskar%2B-%2BPranamasana%2B%2528Prayer%2Bpose%2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.rishikulyogshala.org/wp-content/uploads/2018/12/Pranamasana-Prayer-Pose-820x480.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i0.wp.com/yogamoha.com/wp-content/uploads/2018/04/Pranamasana-Prayer-Pose.jpg?resize=680%2C588
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.healthoj.com/wp-content/uploads/2020/06/parnam-final.jpg
# [Error]Invalid image, not saving http://www.healthoj.com/wp-content/uploads/2020/06/parnam-final.jpg
#
# [!] Issue getting: http://www.healthoj.com/wp-content/uploads/2020/06/parnam-final.jpg
# ...
